# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pil = Image.open("thor.png")
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x525 at 0x168822F6CD0>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (525, 700, 3)

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
work = arr.copy()

# %%
work[:,:,[1,2]].shape
# Out:
# (525, 700, 2)

# %%
work[:,:,[1,2]] = 0

# %%
#only red layer works now
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
#without cmap if we use only gray, then it shows in multicolour grayscale; cmap is colourmap
plt.imshow(gray,cmap = "gray")
